# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'name':['Ashwin','Sanjay','Smita','Vaibhav','Abhijeet','Mahadev','Supriya','Pallavi','Sumeet','Chidambar','Subhash'],
                  'place':['Pune','Satara','Sangli','Solapur','Kolhapur','Pune','Satara','Sangli','Solapur','Pune','Satara'],
                  'age':[42,20,25,36,28,24,45,25,21,19,45]})
df
# Out:
#          name     place  age
# 0      Ashwin      Pune   42
# 1      Sanjay    Satara   20
# 2       Smita    Sangli   25
# 3     Vaibhav   Solapur   36
# 4    Abhijeet  Kolhapur   28
# 5     Mahadev      Pune   24
# 6     Supriya    Satara   45
# 7     Pallavi    Sangli   25
# 8      Sumeet   Solapur   21
# 9   Chidambar      Pune   19
# 10    Subhash    Satara   45

# %%
# I want the records of emp whose age is greater than 30
df[df.age>30]
# Out:
#        name    place  age
# 0    Ashwin     Pune   42
# 3   Vaibhav  Solapur   36
# 6   Supriya   Satara   45
# 10  Subhash   Satara   45

# %%
#I want the emp whose name start with A
df[df.name.str.startswith('A')]
# Out:
#        name     place  age
# 0    Ashwin      Pune   42
# 4  Abhijeet  Kolhapur   28

# %%
# I want the place of an emp whose name endwith a
df[df.name.str.endswith('a')][['place']]
# Out:
#     place
# 2  Sangli
# 6  Satara

# %%
# what is age of Akshay
df[df.name == 'Akshay'].age
# Out:
# Series([], Name: age, dtype: int64)

# %%
# who is from place satara.
df[df.place=='Satara'].name
# Out:
# 1      Sanjay
# 6     Supriya
# 10    Subhash
# Name: name, dtype: object

# %%
# I want to check emp whose age less than or equal to 25
df[df.age<= 25]
# Out:
#         name    place  age
# 1     Sanjay   Satara   20
# 2      Smita   Sangli   25
# 5    Mahadev     Pune   24
# 7    Pallavi   Sangli   25
# 8     Sumeet  Solapur   21
# 9  Chidambar     Pune   19

# %%
# list out name and age of emp from Sangli Location
df = df.query('place=="Sangli"')[["name","age"]]
print(list(np.ravel(df)))
# Out:
# ['Smita', 25, 'Pallavi', 25]

# %%
df
# Out:
#       name  age
# 2    Smita   25
# 7  Pallavi   25

# %%
df = pd.DataFrame({'name':['Ashwin','Sanjay','Smita','Vaibhav','Abhijeet','Mahadev','Supriya','Pallavi','Sumeet','Chidambar','Subhash'],
                  'place':['Pune','Satara','Sangli','Solapur','Kolhapur','Pune','Satara','Sangli','Solapur','Pune','Satara'],
                  'age':[42,20,25,36,28,24,45,25,21,19,45]})
df
# Out:
#          name     place  age
# 0      Ashwin      Pune   42
# 1      Sanjay    Satara   20
# 2       Smita    Sangli   25
# 3     Vaibhav   Solapur   36
# 4    Abhijeet  Kolhapur   28
# 5     Mahadev      Pune   24
# 6     Supriya    Satara   45
# 7     Pallavi    Sangli   25
# 8      Sumeet   Solapur   21
# 9   Chidambar      Pune   19
# 10    Subhash    Satara   45

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.place =[12,11,10,11,8,7,11,10,12,11,12]
df
# Out:
#          name  place  age
# 0      Ashwin     12   42
# 1      Sanjay     11   20
# 2       Smita     10   25
# 3     Vaibhav     11   36
# 4    Abhijeet      8   28
# 5     Mahadev      7   24
# 6     Supriya     11   45
# 7     Pallavi     10   25
# 8      Sumeet     12   21
# 9   Chidambar     11   19
# 10    Subhash     12   45

# %%
#creating a duplicate record
df=df.append({'name':'Aman','place':'pune','age':34},ignore_index=True)
df
# Out:
#          name     place  age
# 0      Ashwin      Pune   42
# 1      Sanjay    Satara   20
# 2       Smita    Sangli   25
# 3     Vaibhav   Solapur   36
# 4    Abhijeet  Kolhapur   28
# 5     Mahadev      Pune   24
# 6     Supriya    Satara   45
# 7     Pallavi    Sangli   25
# 8      Sumeet   Solapur   21
# 9   Chidambar      Pune   19
# 10    Subhash    Satara   45
# 11       Aman        10   34
# 12       Aman      pune   34
# 13       Aman      pune   34

# %%
# Find out is there any duplicate entry
df[df.duplicated()]
# Out:
#     name place  age
# 12  Aman  pune   34
# 13  Aman  pune   34

# %%
# find out the count of null/NaN values
df.isnull().sum()
# Out:
# name     0
# place    0
# age      0
# dtype: int64
